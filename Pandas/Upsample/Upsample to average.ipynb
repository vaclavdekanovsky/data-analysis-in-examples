# %% [markdown]
# # Upsample to average
# Notebook with example for the article on medium.com

# %%
import pandas as pd
import io

# %% [markdown]
# # Downsample

# %%
data="""
CAT|DATE|VALUE
abc|0101|10
abc|0103|20
abc|0107|15"""
df = pd.read_csv(io.StringIO(data), skiprows=1, sep="|", dtype={"DATE":"str"})
df["DATE"] = pd.to_datetime(df["DATE"], format="%m%d")

# %%
df.groupby("CAT").resample("2W", on="DATE").agg({"VALUE":["sum","count","mean","min","max","median","first","last"]})
# Out:
#                VALUE
#                  sum count mean min max median first last
# CAT DATE
# abc 1900-01-07    45     3   15  10  20     15    10   15

# %% [markdown]
# # Upsample

# %%
df.set_index("DATE").groupby("CAT").resample("D").agg({"VALUE":["sum","count","mean","min","max","backfill","bfill","pad","ffill","nearest","first"]})
# Out:
#                VALUE                                                           \
#                  sum count  mean   min   max backfill bfill pad ffill nearest
# CAT DATE
# abc 1900-01-01    10     1  10.0  10.0  10.0       10    10  10    10      10
#     1900-01-02     0     0   NaN   NaN   NaN       20    20  10    10      20
#     1900-01-03    20     1  20.0  20.0  20.0       20    20  20    20      20
#     1900-01-04     0     0   NaN   NaN   NaN       15    15  20    20      20
#     1900-01-05     0     0   NaN   NaN   NaN       15    15  20    20      15
#     1900-01-06     0     0   NaN   NaN   NaN       15    15  20    20      15
#     1900-01-07    15     1  15.0  15.0  15.0       15    15  15    15      15
#
#
#                first
# CAT DATE
# abc 1900-01-01  10.0
#     1900-01-02   NaN
#     1900-01-03  20.0
#     1900-01-04   NaN
#     1900-01-05   NaN
#     1900-01-06   NaN
#     1900-01-07  15.0

# %% [markdown]
# Averaga `mean` didn't really calculate the mean, only filled in the gaps with the `NaN`. To find out the average, you have to use `.group` attribute of the `resample` method and divide the measured value by it. It's more tricky with multiple categories, so let's start with one.

# %%
data="""
CAT|DATE|VALUE
abc|0101|10
abc|0103|20
abc|0106|15"""
df = pd.read_csv(io.StringIO(data), skiprows=1, sep="|", dtype={"DATE":"str"})
df["DATE"] = pd.to_datetime(df["DATE"], format="%m%d")

# %%
expected="""
CAT|DATE|VALUE
abc|0102|10
abc|0103|10
abc|0104|5
abc|0105|5
abc|0106|5"""

# %% [markdown]
# The resample method has two attributes:
#
# * `indices` - showing where the input data appeared
# * `groups` - indexing each datatime value with its group index.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/resampling.html

# %%
# the data came on first, third and sixth of Jan
df.set_index("DATE")\
.resample("D").indices
# Out:
# defaultdict(list,
#             {Timestamp('1900-01-01 00:00:00', freq='D'): [0],
#              Timestamp('1900-01-03 00:00:00', freq='D'): [1],
#              Timestamp('1900-01-06 00:00:00', freq='D'): [2]})

# %%
# the groups are 
""" 
    Jan-1 Group 1
    Jan-2 Group 1
    Jan-3 Group 2
    Jan-4 Group 2
    Jan-5 Group 2
    Jan-6 Group 3
"""
df.set_index("DATE")\
.resample("D", label="right").groups
# Out:
# {Timestamp('1900-01-02 00:00:00', freq='D'): 1,
#  Timestamp('1900-01-03 00:00:00', freq='D'): 1,
#  Timestamp('1900-01-04 00:00:00', freq='D'): 2,
#  Timestamp('1900-01-05 00:00:00', freq='D'): 2,
#  Timestamp('1900-01-06 00:00:00', freq='D'): 2,
#  Timestamp('1900-01-07 00:00:00', freq='D'): 3}

# %% [markdown]
# In reality our data from Jan-1 cover unknown period of time, the value from Jan-3 covers the third and second and the last value covers fourth, fifth and sixth of Jan. We can turn the dictionary returned by the `.groups` parameter into a dataframe and shift the group ids by 1 (row) so that data match our scenario.

# %%
# Calculate the number of hours in each group
resampled_groups = df.set_index("DATE").resample("D", label="right").groups
# alternatively shift the left labels by 1
#df_groups = pd.DataFrame(df.set_index("DATE").resample("D").groups, index=["group"]).T.shift(1)
df_groups = pd.DataFrame(resampled_groups, index=["group"]).T
df_groups
# Out:
#             group
# 1900-01-02      1
# 1900-01-03      1
# 1900-01-04      2
# 1900-01-05      2
# 1900-01-06      2
# 1900-01-07      3

# %% [markdown]
# Knowing which dates belong to each group, let us calculate the number of occurences (days) between each measurement.

# %%
s = df_groups.groupby("group").size()
s.name = "count"
s
# Out:
# group
# 1    2
# 2    3
# 3    1
# Name: count, dtype: int64

# %% [markdown]
# By joining the counts back to the groups we will see how many days were covered each date so that we can calculate the average - measured value at the end of the period/period lenght.

# %%
s_counts = df_groups.join(s, on="group")["count"]
s_counts
# Out:
# 1900-01-02    2
# 1900-01-03    2
# 1900-01-04    3
# 1900-01-05    3
# 1900-01-06    3
# 1900-01-07    1
# Name: count, dtype: int64

# %% [markdown]
# Mering this back to the original dataframe, with backfilled sum allow us to calculate the average.

# %%
res = df.set_index("DATE").resample("D").bfill()
res = res.join(s_counts)
res["average"] = res["VALUE"]/res["count"]
res
# Out:
#             CAT  VALUE  count  average
# DATE
# 1900-01-01  abc     10    NaN      NaN
# 1900-01-02  abc     20    2.0     10.0
# 1900-01-03  abc     20    2.0     10.0
# 1900-01-04  abc     15    3.0      5.0
# 1900-01-05  abc     15    3.0      5.0
# 1900-01-06  abc     15    3.0      5.0

# %% [markdown]
# Voila, we have the values split by average to each day. You might say "hurray", but there's one more pitfall. When you have multiple categories, the `.groups` attribute group all of the together, and doesn't create separate groups per category.

# %%
data="""
CAT|DATE|VALUE
abc|0101|10
abc|0103|20
abc|0106|15
efg|0101|10
efg|0105|40
efg|0106|12"""

# %%
df = pd.read_csv(io.StringIO(data), skiprows=1, sep="|", dtype={"DATE":"str"})
df["DATE"] = pd.to_datetime(df["DATE"], format="%m%d")
df.set_index("DATE").groupby("CAT").resample("D").indices
# Out:
# defaultdict(list,
#             {Timestamp('1900-01-01 00:00:00', freq='D'): [0, 1],
#              Timestamp('1900-01-03 00:00:00', freq='D'): [2],
#              Timestamp('1900-01-05 00:00:00', freq='D'): [3],
#              Timestamp('1900-01-06 00:00:00', freq='D'): [4, 5]})

# %%
df.set_index("DATE").groupby("CAT").resample("D").groups
# Out:
# {Timestamp('1900-01-01 00:00:00', freq='D'): 2,
#  Timestamp('1900-01-02 00:00:00', freq='D'): 2,
#  Timestamp('1900-01-03 00:00:00', freq='D'): 3,
#  Timestamp('1900-01-04 00:00:00', freq='D'): 3,
#  Timestamp('1900-01-05 00:00:00', freq='D'): 4,
#  Timestamp('1900-01-06 00:00:00', freq='D'): 6}

# %% [markdown]
# For this reason you have to to the average calculation separatelly for each group.

# %% [markdown]
# # Putting it all together

# %%
data="""
CAT|DATE|VALUE
abc|0101|10
abc|0103|20
abc|0106|15
efg|0101|10
efg|0105|40
efg|0106|12"""
df = pd.read_csv(io.StringIO(data), skiprows=1, sep="|", dtype={"DATE":"str"})
df["DATE"] = pd.to_datetime(df["DATE"], format="%m%d")

updated_df = []
for gr in df["CAT"].unique():
    
    subdf = df[df["CAT"]==gr].set_index("DATE").resample("1D", label="right")
    
    # back fill the data
    res = subdf.bfill()
    
    # Calculate the number of hours in each group
    resampled_groups = subdf.groups
    df_groups = pd.DataFrame(resampled_groups, index=["group"]).T
    df_groups
    
    s = df_groups.groupby("group").size()
    s.name = "count"
    s_counts = df_groups.join(s, on="group")["count"]
    
    res = res.join(s_counts)
    res["daily_average"] = res["VALUE"]/res["count"]
    
    # add to list
    updated_df.append(res)
    
pd.concat(updated_df).dropna()
# Out:
#             CAT  VALUE  count  daily_average
# DATE
# 1900-01-02  abc     20    2.0           10.0
# 1900-01-03  abc     20    2.0           10.0
# 1900-01-04  abc     15    3.0            5.0
# 1900-01-05  abc     15    3.0            5.0
# 1900-01-06  abc     15    3.0            5.0
# 1900-01-02  efg     40    4.0           10.0
# 1900-01-03  efg     40    4.0           10.0
# 1900-01-04  efg     40    4.0           10.0
# 1900-01-05  efg     40    4.0           10.0
# 1900-01-06  efg     12    1.0           12.0

# %% [markdown]
# In the end, I've dropped all the empty values, because for the first day (the first measurement) we don't know for how long period it's measured.

# %% [markdown]
# You have smoothened your data to daily average, but maybe you don't want to feed the model with daily data. You just needed to cover the different times when the inputs are comming, but now want to input only weekly or quarterly data. That is practically useful in case of stock data, when most of the companies report in September while few does in October or November and some really unfriendly ones does it only every sixth months. In that case you can upsample to average monthly values and then caluclate the rolling average for each quarter and feed your model with lower amount of data.

# %% [markdown]
# Let's explore on this short sample of company data

# %%
data="""
COM|DATE    |VALUE
abc|20200131|100
abc|20200430|80
abc|20200731|125
abc|20201031|110
efg|20200331|25
efg|20200930|75
ijk|20200331|15
ijk|20200630|45
ijk|20200930|50"""

# read the data into dataframe
df = pd.read_csv(io.StringIO(data), skiprows=1, sep="|", dtype={"DATE    ":"str"}).rename(columns={"DATE    ":"DATE"})
df["DATE"] = pd.to_datetime(df["DATE"], format="%Y%m%d")

# %%
updated_df = []
for gr in df["COM"].unique():
    
    subdf = df[df["COM"]==gr].set_index("DATE").resample("M",  label="right", closed="left")
    
    # back fill the data
    res = subdf.bfill()
    
    # Calculate the number of hours in each group
    resampled_groups = subdf.groups
    df_groups = pd.DataFrame(resampled_groups, index=["group"]).T
    df_groups
    
    s = df_groups.groupby("group").size()
    s.name = "count"
    s_counts = df_groups.join(s, on="group")["count"]
    
    res = res.join(s_counts)
    res["monthly_average"] = res["VALUE"]/res["count"]
    
    # add to list
    updated_df.append(res)
    
#av_df = 
av_df = pd.concat(updated_df).dropna()#.reset_index().set_index("DATE")
av_df["3months"] = av_df.groupby("COM")["monthly_average"].rolling(3).sum().values
av_df
# Out:
#             COM  VALUE  count  monthly_average     3months
# DATE
# 2020-02-29  abc     80    3.0        26.666667         NaN
# 2020-03-31  abc     80    3.0        26.666667         NaN
# 2020-04-30  abc     80    3.0        26.666667   80.000000
# 2020-05-31  abc    125    3.0        41.666667   95.000000
# 2020-06-30  abc    125    3.0        41.666667  110.000000
# 2020-07-31  abc    125    3.0        41.666667  125.000000
# 2020-08-31  abc    110    3.0        36.666667  120.000000
# 2020-09-30  abc    110    3.0        36.666667  115.000000
# 2020-10-31  abc    110    3.0        36.666667  110.000000
# 2020-04-30  efg     75    6.0        12.500000         NaN
# 2020-05-31  efg     75    6.0        12.500000         NaN
# 2020-06-30  efg     75    6.0        12.500000   37.500000
# 2020-07-31  efg     75    6.0        12.500000   37.500000
# 2020-08-31  efg     75    6.0        12.500000   37.500000
# 2020-09-30  efg     75    6.0        12.500000   37.500000
# 2020-04-30  ijk     45    3.0        15.000000         NaN
# 2020-05-31  ijk     45    3.0        15.000000         NaN
# 2020-06-30  ijk     45    3.0        15.000000   45.000000
# 2020-07-31  ijk     50    3.0        16.666667   46.666667
# 2020-08-31  ijk     50    3.0        16.666667   48.333333
# 2020-09-30  ijk     50    3.0        16.666667   50.000000

# %%
# for your model you might want only the quartely data
av_df.loc[[pd.to_datetime("2020-06-30"), pd.to_datetime("2020-09-30")]]
# Out:
#             COM  VALUE  count  monthly_average  3months
# DATE
# 2020-06-30  abc    125    3.0        41.666667    110.0
# 2020-06-30  efg     75    6.0        12.500000     37.5
# 2020-06-30  ijk     45    3.0        15.000000     45.0
# 2020-09-30  abc    110    3.0        36.666667    115.0
# 2020-09-30  efg     75    6.0        12.500000     37.5
# 2020-09-30  ijk     50    3.0        16.666667     50.0

# %%
# for your model you might want only the quartely data
av_df\
.loc[[pd.to_datetime("2020-06-30"), pd.to_datetime("2020-09-30")],["COM","3months"]]\
.pivot(columns="COM" ,values="3months")
# Out:
# COM           abc   efg   ijk
# DATE
# 2020-06-30  110.0  37.5  45.0
# 2020-09-30  115.0  37.5  50.0

# %% [markdown]
# ## Why do you need to use label="right", closed="left" with "M"
# Daily and monthly resampling works a bit differently with the groups

# %%
data="""
COM|DATE    |VALUE
efg|20200331|25
efg|20200930|75
efg|20201031|15"""

# read the data into dataframe
df = pd.read_csv(io.StringIO(data), skiprows=1, sep="|", dtype={"DATE    ":"str"}).rename(columns={"DATE    ":"DATE"})
df["DATE"] = pd.to_datetime(df["DATE"], format="%Y%m%d")

# %%
groups = []
for label in ["left","right"]:
    for closed in ["left","right"]:
        resampled_groups = df.set_index("DATE").resample("M", label=label, closed=closed).groups
        groups.append(pd.DataFrame(resampled_groups, index=["l:"+label+"_"+closed]).T)
for label in ["left","right"]:
    resampled_groups = df.set_index("DATE").resample("M", label=label).groups
    groups.append(pd.DataFrame(resampled_groups, index=["l:"+label],dtype="int").T)
out = pd.concat(groups, axis=1).fillna("0").astype("int")

def highlight_cols(s):
    return 'background-color: lightgreen'

out.style.applymap(highlight_cols, subset=pd.IndexSlice[:,["l:right_right","l:right"]])
# Out:
# <style  type="text/css" >
#     #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow0_col3 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow0_col5 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow1_col3 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow1_col5 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow2_col3 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow2_col5 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow3_col3 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow3_col5 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow4_col3 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow4_col5 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow5_col3 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow5_col5 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow6_col3 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow6_col5 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow7_col3 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow7_col5 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow8_col3 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow8_col5 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow9_col3 {
#             background-color:  lightgreen;
#         }    #T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow9_col5 {
#             background-color:  lightgreen;
#         }</style><table id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >l:left_left</th>        <th class="col_heading level0 col1" >l:left_right</th>        <th class="col_heading level0 col2" >l:right_left</th>        <th class="col_heading level0 col3" >l:right_right</th>        <th class="col_heading level0 col4" >l:left</th>        <th class="col_heading level0 col5" >l:right</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row0" class="row_heading level0 row0" >2020-02-29 00:00:00</th>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow0_col1" class="data row0 col1" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow0_col3" class="data row0 col3" >0</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow0_col4" class="data row0 col4" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow0_col5" class="data row0 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row1" class="row_heading level0 row1" >2020-03-31 00:00:00</th>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow1_col4" class="data row1 col4" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow1_col5" class="data row1 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row2" class="row_heading level0 row2" >2020-04-30 00:00:00</th>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow2_col0" class="data row2 col0" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow2_col1" class="data row2 col1" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow2_col3" class="data row2 col3" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow2_col4" class="data row2 col4" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow2_col5" class="data row2 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row3" class="row_heading level0 row3" >2020-05-31 00:00:00</th>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow3_col0" class="data row3 col0" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow3_col1" class="data row3 col1" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow3_col2" class="data row3 col2" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow3_col3" class="data row3 col3" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow3_col4" class="data row3 col4" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow3_col5" class="data row3 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row4" class="row_heading level0 row4" >2020-06-30 00:00:00</th>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow4_col0" class="data row4 col0" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow4_col1" class="data row4 col1" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow4_col2" class="data row4 col2" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow4_col3" class="data row4 col3" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow4_col4" class="data row4 col4" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow4_col5" class="data row4 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row5" class="row_heading level0 row5" >2020-07-31 00:00:00</th>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow5_col0" class="data row5 col0" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow5_col1" class="data row5 col1" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow5_col2" class="data row5 col2" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow5_col3" class="data row5 col3" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow5_col4" class="data row5 col4" >1</td>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow5_col5" class="data row5 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row6" class="row_heading level0 row6" >2020-08-31 00:00:00</th>
#                         <td id="T_095950d8_05b9_11eb_aa4a_af65bbfbe9fdrow6_col0" cla

# %%
data="""
CAT|DATE|VALUE
abc|20200101|10
abc|20200103|20
abc|20200106|15"""
df = pd.read_csv(io.StringIO(data), skiprows=1, sep="|", dtype={"DATE":"str"})
df["DATE"] = pd.to_datetime(df["DATE"], format="%Y%m%d")

# %%
groups = []
for label in ["left","right"]:
    for closed in ["left","right"]:
        resampled_groups = df.set_index("DATE").resample("D", label=label, closed=closed).groups
        groups.append(pd.DataFrame(resampled_groups, index=["l:"+label+"_c:"+closed]).T)

for label in ["left","right"]:
    resampled_groups = df.set_index("DATE").resample("D", label=label).groups
    groups.append(pd.DataFrame(resampled_groups, index=["l:"+label]).T)
        
out = pd.concat(groups, axis=1).fillna("0").astype("int")

def highlight_cols(s):
    return 'background-color: lightgreen'

out.style.applymap(highlight_cols, subset=["l:right_c:left","l:right"])
# Out:
# <style  type="text/css" >
#     #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow0_col2 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow0_col5 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow1_col2 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow1_col5 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow2_col2 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow2_col5 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow3_col2 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow3_col5 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow4_col2 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow4_col5 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow5_col2 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow5_col5 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow6_col2 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow6_col5 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow7_col2 {
#             background-color:  lightgreen;
#         }    #T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow7_col5 {
#             background-color:  lightgreen;
#         }</style><table id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >l:left_c:left</th>        <th class="col_heading level0 col1" >l:left_c:right</th>        <th class="col_heading level0 col2" >l:right_c:left</th>        <th class="col_heading level0 col3" >l:right_c:right</th>        <th class="col_heading level0 col4" >l:left</th>        <th class="col_heading level0 col5" >l:right</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row0" class="row_heading level0 row0" >2019-12-31 00:00:00</th>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow0_col1" class="data row0 col1" >1</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow0_col3" class="data row0 col3" >0</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow0_col5" class="data row0 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row1" class="row_heading level0 row1" >2020-01-01 00:00:00</th>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow1_col4" class="data row1 col4" >1</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow1_col5" class="data row1 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row2" class="row_heading level0 row2" >2020-01-02 00:00:00</th>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow2_col0" class="data row2 col0" >1</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow2_col1" class="data row2 col1" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow2_col3" class="data row2 col3" >1</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow2_col4" class="data row2 col4" >1</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow2_col5" class="data row2 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row3" class="row_heading level0 row3" >2020-01-03 00:00:00</th>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow3_col0" class="data row3 col0" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow3_col1" class="data row3 col1" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow3_col2" class="data row3 col2" >1</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow3_col3" class="data row3 col3" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow3_col4" class="data row3 col4" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow3_col5" class="data row3 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row4" class="row_heading level0 row4" >2020-01-04 00:00:00</th>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow4_col0" class="data row4 col0" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow4_col1" class="data row4 col1" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow4_col2" class="data row4 col2" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow4_col3" class="data row4 col3" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow4_col4" class="data row4 col4" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow4_col5" class="data row4 col5" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row5" class="row_heading level0 row5" >2020-01-05 00:00:00</th>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow5_col0" class="data row5 col0" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow5_col1" class="data row5 col1" >3</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow5_col2" class="data row5 col2" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow5_col3" class="data row5 col3" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow5_col4" class="data row5 col4" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow5_col5" class="data row5 col5" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdlevel0_row6" class="row_heading level0 row6" >2020-01-06 00:00:00</th>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow6_col0" class="data row6 col0" >3</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow6_col1" class="data row6 col1" >0</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow6_col2" class="data row6 col2" >2</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4a_af65bbfbe9fdrow6_col3" class="data row6 col3" >3</td>
#                         <td id="T_0966f7b0_05b9_11eb_aa4
